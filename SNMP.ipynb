# %%
Simple Network Management Protocol (SNMP) is an Internet Standard protocol for collecting and organizing information about managed devices on IP networks and for modifying that information to change device behaviour. Devices that typically support SNMP include cable modems, routers, switches, servers, workstations, printers, and more.[1]

SNMP is widely used in network management for network monitoring. SNMP exposes management data in the form of variables on the managed systems organized in a management information base (MIB) which describe the system status and configuration. These variables can then be remotely queried (and, in some circumstances, manipulated) by managing applications.

Three significant versions of SNMP have been developed and deployed. SNMPv1 is the original version of the protocol. More recent versions, SNMPv2c and SNMPv3, feature improvements in performance, flexibility and security.

SNMP is a component of the Internet Protocol Suite as defined by the Internet Engineering Task Force (IETF). It consists of a set of standards for network management, including an application layer protocol, a database schema, and a set of data objects.[2]

# %%
# List popular devices applicable to each version 
SNMPv1:

Cable modems
Routers
Switches
Servers
Workstations
Printers
SNMPv2c:

Cable modems
Routers
Switches
Servers
Workstations
Printers
Firewalls
Wireless access points
Network-attached storage (NAS) devices
SNMPv3:

Cable modems
Routers
Switches
Servers
Workstations
Printers
Firewalls
Wireless access points
Network-attached storage (NAS) devices
Load balancers
VPN gateways

# %%
Cable modems:

Vendor: Arris, Technicolor
MIB: DOCSIS-MIB
Information needed:
Object Identifier (OID) of the trap you want to receive
Information about the event that triggers the trap
Severity level of the event
Description of the event
Routers:

Vendor: Cisco, Juniper, Huawei
MIB: CISCO-MIB, JUNIPER-MIB, HUAWEI-MIB
Information needed:
Object Identifier (OID) of the trap you want to receive
Information about the event that triggers the trap
Severity level of the event
Description of the event
Switches:

Vendor: Cisco, HPE, Juniper
MIB: CISCO-MIB, HP-MIB, JUNIPER-MIB
Information needed:
Object Identifier (OID) of the trap you want to receive
Information about the event that triggers the trap
Severity level of the event
Description of the event
Servers:

Vendor: Dell, HPE, IBM
MIB: DELL-MIB, HP-MIB, IBM-MIB
Information needed:
Object Identifier (OID) of the trap you want to receive
Information about the event that triggers the trap
Severity level of the event
Description of the event
Workstations:

Vendor: Dell, HPE, Lenovo
MIB: DELL-MIB, HP-MIB, LENOVO-MIB
Information needed:
Object Identifier (OID) of the trap you want to receive
Information about the event that triggers the trap
Severity level of the event
Description of the event
Printers:

Vendor: HP, Lexmark, Xerox
MIB: HP-MIB, LEXMARK-MIB, XEROX-MIB
Information needed:
Object Identifier (OID) of the trap you want to receive
Information about the event that triggers the trap
Severity level of the event
Description of the event
Firewalls:

Vendor: Cisco, Juniper, Fortinet
MIB: CISCO-MIB, JUNIPER-MIB, FORTINET-MIB
Information needed:
Object Identifier (OID) of the trap you want to receive
Information about the event that triggers the trap
Severity level of the event
Description of the event
Wireless access points:

Vendor: Cisco, Aruba, Ruckus
MIB: CISCO-MIB, ARUBA-MIB, RUCKUS-MIB
Information needed:
Object Identifier (OID) of the trap you want to receive
Information about the event that triggers the trap
Severity level of the event
Description of the event
Network-attached storage (NAS) devices:

Vendor: Synology, QNAP, Netgear
MIB: SYNOLOGY-MIB, QNAP-MIB, NETGEAR-
Information needed:
Object Identifier (OID) of the trap you want to receive
Information about the event that triggers the trap
Severity level of the event
Description of the event
Load balancers:

Vendor: F5, A10, Citrix
MIB: F5-MIB, A10-MIB, CITRIX-MIB
Information needed:
Object Identifier (OID) of the trap you want to receive
Information about the event that triggers the trap
Severity level of the event
Description of the event
VPN gateways:

Vendor: Cisco, Juniper, Fortinet
MIB: CISCO-MIB, JUNIPER-MIB, FORTINET-MIB
Information needed:
Object Identifier (OID) of the trap you want to receive
Information about the event that triggers the trap
Severity level of the event
Description of the event
